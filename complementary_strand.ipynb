# %% [markdown]
# <a href="https://colab.research.google.com/github/kimiamhr/kimiamhr/blob/main/complementary_strand.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
dna = "..."
rev = dna[::-1]
rna = ""
for x in rev:
  if x == "A":
      u = "T"
      rna= rna + u
  if x == "C":
      g = "G"
      rna= rna + g
  if x == "G":
      c = "C"
      rna= rna + c
  if x == "T":
      a = "A"
      rna= rna + a
print(rna)
# Out:
# ...
